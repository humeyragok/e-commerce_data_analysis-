# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("project1_df.csv")
df.head()
# Out:
#       CID         TID  Gender     Age Group        Purchase Date  \
# 0  943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1  180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2  337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3  180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4  447553  8009390577    Male         18-25  31/05/2022 17:00:32
#
#    Product Category Discount Availed    Discount Name  Discount Amount (INR)  \
# 0       Electronics              Yes        FESTIVE50                  64.30
# 1       Electronics              Yes  SEASONALOFFER21                 175.19
# 2          Clothing              Yes  SEASONALOFFER21                 211.54
# 3  Sports & Fitness               No              NaN                   0.00
# 4  Sports & Fitness              Yes         WELCOME5                 439.92
#
#    Gross Amount   Net Amount Purchase Method   Location
# ...

# %%
df.columns
# Out:
# Index(['CID', 'TID', 'Gender', 'Age Group', 'Purchase Date',
#        'Product Category', 'Discount Availed', 'Discount Name',
#        'Discount Amount (INR)', 'Gross Amount', 'Net Amount',
#        'Purchase Method', 'Location'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# CID                          0
# TID                          0
# Gender                       0
# Age Group                    0
# Purchase Date                0
# Product Category             0
# Discount Availed             0
# Discount Name            27585
# Discount Amount (INR)        0
# Gross Amount                 0
# Net Amount                   0
# Purchase Method              0
# Location                     0
# dtype: int64

# %%
# Fill missing values in the 'Discount Name' column with the mean
df["Discount Name"].fillna(df["Discount Name"].mode(), inplace=True)

# %%
df.isnull().sum()
# Out:
# CID                          0
# TID                          0
# Gender                       0
# Age Group                    0
# Purchase Date                0
# Product Category             0
# Discount Availed             0
# Discount Name            27585
# Discount Amount (INR)        0
# Gross Amount                 0
# Net Amount                   0
# Purchase Method              0
# Location                     0
# dtype: int64

# %%
df["Discount Name"]
# Out:
# 0              FESTIVE50
# 1        SEASONALOFFER21
# 2        SEASONALOFFER21
# 3                    NaN
# 4               WELCOME5
#               ...
# 54995    SEASONALOFFER21
# 54996    SEASONALOFFER21
# 54997           NEWYEARS
# 54998    SEASONALOFFER21
# 54999           NEWYEARS
# Name: Discount Name, Length: 55000, dtype: object

# %%
# Fill missing values in the 'Discount Name' column with the mean
df["Discount Name"].fillna(df["Discount Name"].mode()[0], inplace=True)

# %%
df["Discount Name"]
# Out:
# 0              FESTIVE50
# 1        SEASONALOFFER21
# 2        SEASONALOFFER21
# 3               NEWYEARS
# 4               WELCOME5
#               ...
# 54995    SEASONALOFFER21
# 54996    SEASONALOFFER21
# 54997           NEWYEARS
# 54998    SEASONALOFFER21
# 54999           NEWYEARS
# Name: Discount Name, Length: 55000, dtype: object

# %%
df.columns
# Out:
# Index(['CID', 'TID', 'Gender', 'Age Group', 'Purchase Date',
#        'Product Category', 'Discount Availed', 'Discount Name',
#        'Discount Amount (INR)', 'Gross Amount', 'Net Amount',
#        'Purchase Method', 'Location'],
#       dtype='object')

# %%
df.head()
# Out:
#       CID         TID  Gender     Age Group        Purchase Date  \
# 0  943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1  180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2  337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3  180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4  447553  8009390577    Male         18-25  31/05/2022 17:00:32
#
#    Product Category Discount Availed    Discount Name  Discount Amount (INR)  \
# 0       Electronics              Yes        FESTIVE50                  64.30
# 1       Electronics              Yes  SEASONALOFFER21                 175.19
# 2          Clothing              Yes  SEASONALOFFER21                 211.54
# 3  Sports & Fitness               No         NEWYEARS                   0.00
# 4  Sports & Fitness              Yes         WELCOME5                 439.92
#
#    Gross Amount   Net Amount Purchase Method   Location
# ...

# %%
df.describe()
# Out:
#                  CID           TID  Discount Amount (INR)  Gross Amount  \
# count   55000.000000  5.500000e+04           55000.000000  55000.000000
# mean   551245.593891  5.504740e+09             136.986796   3012.936606
# std    260603.330337  2.594534e+09             165.375502   1718.431066
# min    100009.000000  1.000163e+09               0.000000    136.454325
# 25%    323717.000000  3.252604e+09               0.000000   1562.111325
# 50%    550088.500000  5.498383e+09               0.000000   2954.266150
# 75%    776955.750000  7.747933e+09             274.115000   4342.221675
# max    999996.000000  9.999393e+09             500.000000   8394.825600
#
#          Net Amount
# count  55000.000000
# mean    2875.949810
# std     1726.127778
# min     -351.119775
# 25%     1429.551863
# 50%     2814.910875
# 75%     4211.407838
# max     8394.825600

# %%
df.drop(["CID","TID","Gross Amount"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Gender     Age Group        Purchase Date  Product Category  \
# 0  Female         25-45  30/08/2023 20:27:08       Electronics
# 1    Male         25-45  23/02/2024 09:33:46       Electronics
# 2   Other  60 and above  06/03/2022 09:09:50          Clothing
# 3   Other  60 and above  04/11/2020 04:41:57  Sports & Fitness
# 4    Male         18-25  31/05/2022 17:00:32  Sports & Fitness
#
#   Discount Availed    Discount Name  Discount Amount (INR)   Net Amount  \
# 0              Yes        FESTIVE50                  64.30   661.004000
# 1              Yes  SEASONALOFFER21                 175.19  4463.801875
# 2              Yes  SEASONALOFFER21                 211.54  1774.832575
# 3               No         NEWYEARS                   0.00  5695.612650
# 4              Yes         WELCOME5                 439.92  1852.731500
#
#   Purchase Method   Location
# 0     Credit Card  Ahmedabad
# 1     Credit Card  Bangalore
# 2     Credit Card      Delhi
# 3      Debit Card      Delhi
# ...

# %%
#Aylara göre dağılım için yeni bir sütun oluştur
df["Month"]=df["Purchase Date"].str[3:5]
df
# Out:
#        Gender     Age Group        Purchase Date   Product Category  \
# 0      Female         25-45  30/08/2023 20:27:08        Electronics
# 1        Male         25-45  23/02/2024 09:33:46        Electronics
# 2       Other  60 and above  06/03/2022 09:09:50           Clothing
# 3       Other  60 and above  04/11/2020 04:41:57   Sports & Fitness
# 4        Male         18-25  31/05/2022 17:00:32   Sports & Fitness
# ...       ...           ...                  ...                ...
# 54995   Other         25-45  23/02/2020 10:42:04        Electronics
# 54996   Other         18-25  12/07/2021 15:59:21        Electronics
# 54997    Male         45-60  02/08/2024 09:30:44     Home & Kitchen
# 54998  Female         45-60  05/08/2020 23:57:56  Beauty and Health
# 54999    Male         25-45  21/07/2022 09:05:18  Beauty and Health
#
#       Discount Availed    Discount Name  Discount Amount (INR)   Net Amount  \
# ...

# %%
df["Month"]=df["Month"].astype("int32")
df
# Out:
#        Gender     Age Group        Purchase Date   Product Category  \
# 0      Female         25-45  30/08/2023 20:27:08        Electronics
# 1        Male         25-45  23/02/2024 09:33:46        Electronics
# 2       Other  60 and above  06/03/2022 09:09:50           Clothing
# 3       Other  60 and above  04/11/2020 04:41:57   Sports & Fitness
# 4        Male         18-25  31/05/2022 17:00:32   Sports & Fitness
# ...       ...           ...                  ...                ...
# 54995   Other         25-45  23/02/2020 10:42:04        Electronics
# 54996   Other         18-25  12/07/2021 15:59:21        Electronics
# 54997    Male         45-60  02/08/2024 09:30:44     Home & Kitchen
# 54998  Female         45-60  05/08/2020 23:57:56  Beauty and Health
# 54999    Male         25-45  21/07/2022 09:05:18  Beauty and Health
#
#       Discount Availed    Discount Name  Discount Amount (INR)   Net Amount  \
# ...

# %%
#ayları isimlere dönüştür
aylar={1:"Ocak",2:"Şubat",3:"Mart",4:"Nisan",5:"Mayıs",6:"Haziran",7:"Temmuz",8:"Ağustos",9:"Eylül",10:"Ekim",11:"Kasım",12:"Aralık"}

# %%
df["Month"]=[aylar[i] for i in df["Month"]]
df
# Out:
#        Gender     Age Group        Purchase Date   Product Category  \
# 0      Female         25-45  30/08/2023 20:27:08        Electronics
# 1        Male         25-45  23/02/2024 09:33:46        Electronics
# 2       Other  60 and above  06/03/2022 09:09:50           Clothing
# 3       Other  60 and above  04/11/2020 04:41:57   Sports & Fitness
# 4        Male         18-25  31/05/2022 17:00:32   Sports & Fitness
# ...       ...           ...                  ...                ...
# 54995   Other         25-45  23/02/2020 10:42:04        Electronics
# 54996   Other         18-25  12/07/2021 15:59:21        Electronics
# 54997    Male         45-60  02/08/2024 09:30:44     Home & Kitchen
# 54998  Female         45-60  05/08/2020 23:57:56  Beauty and Health
# 54999    Male         25-45  21/07/2022 09:05:18  Beauty and Health
#
#       Discount Availed    Discount Name  Discount Amount (INR)   Net Amount  \
# ...
